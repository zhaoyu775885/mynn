# %%
import torch
import torch.nn as nn
from torchtext import data

# %%
tokenize = lambda x: x.split()
TEXT = data.Field(init_token='<SOS>', eos_token='<EOS>', tokenize=tokenize, lower=True)
LABEL = data.Field(sequential=False, use_vocab=False)

# %%
def raw_info(vocab, ID_list):
    length, bsz = ID_list.shape
    for _ in range(bsz):
        for i in range(length):
            print(vocab.itos[ID_list[i,_]], end=' ')
        print()

# %%
data_path = '/home/zhaoyu/Datasets/NLPBasics/sentiment/train.tsv'
dataset = data.TabularDataset(data_path, 'TSV', skip_header=True, 
                              fields=[('PhraseId', LABEL), ('SentenceId', LABEL),
                                      ('Phrase', TEXT), ('Sentiment', LABEL)])
TEXT.build_vocab(dataset)
vocab = TEXT.vocab

# %%
train_iter = data.BucketIterator(dataset, batch_size=4, 
                                 train=True,
                                 sort=True,
                                 shuffle=True, 
                                 sort_within_batch=False,
                                 sort_key=lambda x: len(x.Phrase),
                                 repeat=False)

print('train:', train_iter.train, '\nsort:', train_iter.sort, 
      '\nshuffle:', train_iter.shuffle)
# Out:
# train: True
# sort: True
# shuffle: True

# %%
for i, batch in enumerate(train_iter):
    if i>10000 and i<10100:
        print(i, batch.Sentiment, batch.Phrase.shape)
        raw_info(vocab, batch.Phrase)
    if i>10100:
        break
# Out:
# 10001 tensor([2, 2, 3, 2]) torch.Size([4, 4])
# <SOS> have never <EOS>
# <SOS> a lock <EOS>
# <SOS> expert fighters <EOS>
# <SOS> few weeks <EOS>
# 10002 tensor([2, 3, 1, 2]) torch.Size([4, 4])
# <SOS> actually shocked <EOS>
# <SOS> it succeeds <EOS>
# <SOS> many improbabilities <EOS>
# <SOS> rose-colored situations <EOS>
# 10003 tensor([3, 3, 2, 2]) torch.Size([4, 4])
# <SOS> impacting film <EOS>
# <SOS> great documentaries <EOS>
# <SOS> one truth <EOS>
# <SOS> administration 's <EOS>
# 10004 tensor([2, 2, 2, 2]) torch.Size([4, 4])
# <SOS> tearing ` <EOS>
# <SOS> their mothers <EOS>
# <SOS> have noticed <EOS>
# <SOS> take nothing <EOS>
# 10005 tensor([2, 2, 1, 2]) torch.Size([4, 4])
# <SOS> seems -rrb- <EOS>
# <SOS> uselessly redundant <EOS>
# <SOS> shamelessly money-grubbing <EOS>
# <SOS> horror sequels <EOS>
# 10006 tensor([2, 4, 2, 2]) torch.Size([4, 4])
# <SOS> apocalypse movies <EOS>
# <SOS> confidently orchestrated <EOS>
# <SOS> aesthetically and <EOS>
# <SOS> deeply and <EOS>
# 10007 tensor([3, 2, 2, 2]) torch.Size([4, 4])
# <SOS> soulful and <EOS>
# <SOS> movie career <EOS>
# <SOS> shooting fish <EOS>
# <SOS> a barrel <EOS>
# 10008 tensor([2, 4, 1, 2]) torch.Size([4, 4])
# <SOS> based-on-truth stories <EOS>
# <SOS> persuades you <EOS>
# <SOS> too fancy <EOS>
# <SOS> too filling <EOS>
# 10009 tensor([1, 3, 3, 2]) torch.Size([4, 4])
# <SOS> too fluffy <EOS>
# <SOS> tasty and <EOS>
# <SOS> rare insight <EOS>
# <SOS> of relationships <EOS>
# 10010 tensor([2, 2, 3, 3]) torch.Size([4, 4])
# <SOS> tonal shifts <EOS>
# <SOS> are jolting <EOS>
# <SOS> profound and <EOS>
# <SOS> thoughtfully delivered <EOS>
# 10011 tensor([3, 3, 2, 2]) torch.Size([4, 4])
# <SOS> thorough transitions <EOS>
# <SOS> more cohesive <EOS>
# <SOS> a surplus <EOS>
# <SOS> archive footage <EOS>
# 10012 tensor([2, 3, 2, 2]) torch.Size([4, 4])
# <SOS> odd distinction <EOS>
# <SOS> being fun <EOS>
# <SOS> seagal , <EOS>
# <SOS> danny aiello <EOS>
# 10013 tensor([2, 2, 3, 2]) torch.Size([4, 4])
# <SOS> literary conceits <EOS>
# <SOS> flesh-and-blood humans <EOS>
# <SOS> winning piece <EOS>
# <SOS> is static <EOS>
# 10014 tensor([2, 2, 3, 2]) torch.Size([4, 4])
# <SOS> writer-director 's <EOS>
# <SOS> his plea <EOS>
# <SOS> action laudable <EOS>
# <SOS> griffin & <EOS>
# 10015 tensor([3, 2, 2, 2]) torch.Size([4, 4])
# <SOS> spectacularly outrageous <EOS>
# <SOS> english patient <EOS>
# <SOS> unbearable lightness <EOS>
# <SOS> of being <EOS>
# 10016 tensor([2, 2, 2, 2]) torch.Size([4, 4])
# <SOS> '' novels <EOS>
# <SOS> focus '' <EOS>
# <SOS> biopic and <EOS>
# <SOS> male swingers <EOS>
# 10017 tensor([2, 2, 3, 2]) torch.Size([4, 4])
# <SOS> playboy era <EOS>
# <SOS> usual route <EOS>
# <SOS> sometimes both <EOS>
# <SOS> pokes , <EOS>
# 10018 tensor([3, 2, 2, 2]) torch.Size([4, 4])
# <SOS> expressionistic license <EOS>
# <SOS> mission accomplished <EOS>
# <SOS> and at <EOS>
# <SOS> a block <EOS>
# 10019 tensor([2, 0, 2, 2]) torch.Size([4, 4])
# <SOS> of snow <EOS>
# <SOS> sad sack <EOS>
# <SOS> his chemistry <EOS>
# <SOS> with shimizu <EOS>
# 10020 tensor([3, 2, 3, 2]) torch.Size([4, 4])
# <SOS> very believable <EOS>
# <SOS> no means <EOS>
# <SOS> a slam-dunk <EOS>
# <SOS> clinically depressed <EOS>
# 10021 tensor([2, 2, 2, 3]) torch.Size([4, 4])
# <SOS> hopes and <EOS>
# <SOS> rambo - <EOS>
# <SOS> meets-john ford <EOS>
# <SOS> in marriage <EOS>
# 10022 tensor([2, 1, 3, 2]) torch.Size([4, 4])
# <SOS> real issues <EOS>
# <SOS> crude storyline <EOS>
# <SOS> costner 's <EOS>
# <SOS> warm-milk persona <EOS>
# 10023 tensor([2, 1, 2, 2]) torch.Size([4, 4])
# <SOS> directing chops <EOS>
# <SOS> overtly silly <EOS>
# <SOS> laurence olivier <EOS>
# <SOS> hang together <EOS>
# 10024 tensor([2, 4, 3, 2]) torch.Size([4, 4])
# <SOS> combine easily <EOS>
# <SOS> perfect show <EOS>
# <SOS> underrated professionals <EOS>
# <SOS> deserve but <EOS>
# 10025 tensor([2, 2, 2, 2]) torch.Size([4, 4])
# <SOS> receive it <EOS>
# <SOS> sad evidence <EOS>
# <SOS> tom tykwer <EOS>
# <SOS> the resonant <EOS>
# 10026 tensor([2, 2, 1, 2]) torch.Size([4, 4])
# <SOS> lola run <EOS>
# <SOS> turned out <EOS>
# <SOS> one-trick pony <EOS>
# <SOS> a maker <EOS>
# 10027 tensor([1, 2, 2, 2]) torch.Size([4, 4])
# <SOS> metaphysical claptrap <EOS>
# <SOS> procedural details <EOS>
# <SOS> a dogged <EOS>
# <SOS> the darling <EOS>
# 10028 tensor([1, 3, 2, 0]) torch.Size([4, 4])
# <SOS> cable channel <EOS>
# <SOS> a vivid <EOS>
# <SOS> sometimes surreal <EOS>
# <SOS> 94-minute travesty <EOS>
# 10029 tensor([3, 2, 2, 2]) torch.Size([4, 4])
# <SOS> unparalleled proportions <EOS>
# <SOS> writer-director parker <EOS>
# <SOS> wit 's <EOS>
# <SOS> identity farce <EOS>
# 10030 tensor([2, 2, 3, 2]) torch.Size([4, 4])
# <SOS> labored and <EOS>
# <SOS> nalin 's <EOS>
# <SOS> beautiful and <EOS>
# <SOS> the interviews <EOS>
# 10031 tensor([2, 2, 2, 2]) torch.Size([4, 4])
# <SOS> that follow <EOS>
# <SOS> the practitioners <EOS>
# <SOS> indian practice <EOS>
# <SOS> as enigmatic <EOS>
# 10032 tensor([2, 2, 2, 1]) torch.Size([4, 4])
# <SOS> holiday cheer <EOS>
# <SOS> fool you <EOS>
# <SOS> a monopoly <EOS>
# <SOS> mindless action <EOS>
# 10033 tensor([2, 2, 2, 2]) torch.Size([4, 4])
# <SOS> be acted <EOS>
# <SOS> impressionable kid <EOS>
# <SOS> to hear <EOS>
# <SOS> both worlds <EOS>
# 10034 tensor([1, 2, 3, 2]) torch.Size([4, 4])
# <SOS> falling short <EOS>
# <SOS> saves it <EOS>
# <SOS> better video-game-based <EOS>
# <SOS> flicks , <EOS>
# 10035 tensor([2, 3, 2, 2]) torch.Size([4, 4])
# <SOS> of linearity <EOS>
# <SOS> emotional and <EOS>
# <SOS> protagonist alice <EOS>
# <SOS> necessary enterprise <EOS>
# 10036 tensor([2, 3, 3, 3]) torch.Size([4, 4])
# <SOS> the trailer <EOS>
# <SOS> a riot <EOS>
# <SOS> enthralling documentary <EOS>
# <SOS> playful and <EOS>
# 10037 tensor([3, 2, 2, 2]) torch.Size([4, 4])
# <SOS> in-depth portrait <EOS>
# <SOS> iconoclastic artist <EOS>
# <SOS> fundamentally unknowable <EOS>
# <SOS> closest friends <EOS>
# 10038 tensor([3, 2, 2, 2]) torch.Size([4, 4])
# <SOS> engaging criminal <EOS>
# <SOS> guessing just <EOS>
# <SOS> the finale <EOS>
# <SOS> sure and <EOS>
# 10039 tensor([2, 2, 3, 2]) torch.Size([4, 4])
# <SOS> haneke -rrb- <EOS>
# <SOS> steers clear <EOS>
# <SOS> the sensational <EOS>
# <SOS> offers instead <EOS>
# 10040 tensor([2, 2, 1, 3]) torch.Size([4, 4])
# <SOS> objective look <EOS>
# <SOS> decidedly perverse <EOS>
# <SOS> tiresome nature <EOS>
# <SOS> of complacency <EOS>
# 10041 tensor([2, 3, 2, 2]) torch.Size([4, 4])
# <SOS> same throughout <EOS>
# <SOS> pretty well <EOS>
# <SOS> movie experiences <EOS>
# <SOS> its imagery <EOS>
# 10042 tensor([2, 0, 2, 2]) torch.Size([4, 4])
# <SOS> ponder anew <EOS>
# <SOS> dull girl <EOS>
# <SOS> macdowell 's <EOS>
# <SOS> personal odyssey <EOS>
# 10043 tensor([2, 2, 1, 2]) torch.Size([4, 4])
# <SOS> the carnage <EOS>
# <SOS> around her <EOS>
# <SOS> environmental pollution <EOS>
# <SOS> the wake <EOS>
# 10044 tensor([1, 2, 1, 2]) torch.Size([4, 4])
# <SOS> heartily sick <EOS>
# <SOS> of mayhem <EOS>
# <SOS> war-weary marine <EOS>
# <SOS> the holes <EOS>
# 10045 tensor([2, 2, 1, 2]) torch.Size([4, 4])
# <SOS> remain agape <EOS>
# <SOS> punched through <EOS>
# <SOS> sometimes dry <EOS>
# <SOS> looking down <EOS>
# 10046 tensor([2, 2, 3, 3]) torch.Size([4, 4])
# <SOS> even halfway <EOS>
# <SOS> soberly reported <EOS>
# <SOS> an inventive <EOS>
# <SOS> absorbing movie <EOS>
# 10047 tensor([2, 2, 2, 4]) torch.Size([4, 4])
# <SOS> piece , <EOS>
# <SOS> a model <EOS>
# <SOS> in scope <EOS>
# <SOS> perfectly formed <EOS>
# 10048 tensor([3, 2, 2, 2]) torch.Size([4, 4])
# <SOS> career peak <EOS>
# <SOS> werner herzog <EOS>
# <SOS> leave us <EOS>
# <SOS> of wonder <EOS>
# 10049 tensor([3, 2, 1, 1]) torch.Size([4, 4])
# <SOS> shapes history <EOS>
# <SOS> has taken <EOS>
# <SOS> too self-satisfied <EOS>
# <SOS> be profane <EOS>
# 10050 tensor([2, 2, 2, 2]) torch.Size([4, 4])
# <SOS> charged music <EOS>
# <SOS> the ears <EOS>
# <SOS> pay your <EOS>
# <SOS> $ 8 <EOS>
# 10051 tensor([2, 3, 2, 2]) torch.Size([4, 4])
# <SOS> get ready <EOS>
# <SOS> big shear <EOS>
# <SOS> verite speculation <EOS>
# <SOS> the assassination <EOS>
# 10052 tensor([2, 2, 3, 1]) torch.Size([4, 4])
# <SOS> f. kennedy <EOS>
# <SOS> its techniques <EOS>
# <SOS> fresh territory <EOS>
# <SOS> feels derivative <EOS>
# 10053 tensor([2, 2, 2, 3]) torch.Size([4, 4])
# <SOS> the looseness <EOS>
# <SOS> the shapeless <EOS>
# <SOS> flat script <EOS>
# <SOS> suspenseful spin <EOS>
# 10054 tensor([2, 2, 2, 3]) torch.Size([4, 4])
# <SOS> 're doing <EOS>
# <SOS> mind games <EOS>
# <SOS> erotic or <EOS>
# <SOS> that proceeds <EOS>
# 10055 tensor([0, 2, 2, 1]) torch.Size([4, 4])
# <SOS> stunningly unoriginal <EOS>
# <SOS> each story <EOS>
# <SOS> first two <EOS>
# <SOS> by amateurish <EOS>
# 10056 tensor([2, 1, 2, 2]) torch.Size([4, 4])
# <SOS> the third <EOS>
# <SOS> short running <EOS>
# <SOS> story or <EOS>
# <SOS> for editing <EOS>
# 10057 tensor([2, 2, 3, 3]) torch.Size([4, 4])
# <SOS> much shorter <EOS>
# <SOS> smoother , <EOS>
# <SOS> more focused <EOS>
# <SOS> cultural intrigue <EOS>
# 10058 tensor([3, 2, 1, 2]) torch.Size([4, 4])
# <SOS> hugely entertaining <EOS>
# <SOS> of letting <EOS>
# <SOS> trademark misogyny <EOS>
# <SOS> er , <EOS>
# 10059 tensor([2, 1, 2, 1]) torch.Size([4, 4])
# <SOS> human volcano <EOS>
# <SOS> septic tank <EOS>
# <SOS> paradiso 's <EOS>
# <SOS> rusted-out ruin <EOS>
# 10060 tensor([2, 2, 4, 2]) torch.Size([4, 4])
# <SOS> ultimate collapse <EOS>
# <SOS> restored -rrb- <EOS>
# <SOS> cinema classic <EOS>
# <SOS> quite diverting <EOS>
# 10061 tensor([0, 2, 2, 2]) torch.Size([4, 4])
# <SOS> utterly pointless <EOS>
# <SOS> underplayed melodrama <EOS>
# <SOS> dynamics and <EOS>
# <SOS> harks back <EOS>
# 10062 tensor([1, 2, 2, 2]) torch.Size([4, 4])
# <SOS> unchecked heartache <EOS>
# <SOS> yasujiro ozu <EOS>
# <SOS> unseemly pleasure <EOS>
# <SOS> congratulate himself <EOS>
# 10063 tensor([3, 2, 2, 2]) torch.Size([4, 4])
# <SOS> confront it <EOS>
# <SOS> american psycho <EOS>
# <SOS> claws enough <EOS>
# <SOS> inside you <EOS>
# 10064 tensor([2, 2, 1, 3]) torch.Size([4, 4])
# <SOS> stay there <EOS>
# <SOS> of hours <EOS>
# <SOS> is callow <EOS>
# <SOS> thoughtful consideration <EOS>
# 10065 tensor([2, 2, 2, 2]) torch.Size([4, 4])
# <SOS> of fatherhood <EOS>
# <SOS> best trick <EOS>
# <SOS> treats conspiracy <EOS>
# <SOS> monstrous murk <EOS>
# 10066 tensor([2, 2, 4, 2]) torch.Size([4, 4])
# <SOS> haunts us <EOS>
# <SOS> be seen <EOS>
# <SOS> extraordinary film <EOS>
# <SOS> is japanese <EOS>
# 10067 tensor([3, 2, 1, 2]) torch.Size([4, 4])
# <SOS> feels universal <EOS>
# <SOS> brendan fraser <EOS>
# <SOS> temperamental child <EOS>
# <SOS> giving audiences <EOS>
# 10068 tensor([1, 3, 0, 1]) torch.Size([4, 4])
# <SOS> decrepit freaks <EOS>
# <SOS> a reprieve <EOS>
# <SOS> incessant whining <EOS>
# <SOS> shooting itself <EOS>
# 10069 tensor([2, 2, 2, 2]) torch.Size([4, 4])
# <SOS> the foot <EOS>
# <SOS> big daddy <EOS>
# <SOS> as anarchic <EOS>
# <SOS> happy gilmore <EOS>
# 10070 tensor([2, 2, 2, 2]) torch.Size([4, 4])
# <SOS> the waterboy <EOS>
# <SOS> but mush-hearted <EOS>
# <SOS> achronological vignettes <EOS>
# <SOS> whose cumulative <EOS>
# 10071 tensor([2, 2, 3, 2]) torch.Size([4, 4])
# <SOS> is chilling <EOS>
# <SOS> third row <EOS>
# <SOS> imax cinema <EOS>
# <SOS> sydney 's <EOS>
# 10072 tensor([2, 2, 2, 2]) torch.Size([4, 4])
# <SOS> darling harbour <EOS>
# <SOS> seater plane <EOS>
# <SOS> giant camera <EOS>
# <SOS> around australia <EOS>
# 10073 tensor([2, 2, 2, 2]) torch.Size([4, 4])
# <SOS> sweeping and <EOS>
# <SOS> just a <EOS>
# <SOS> a stitch <EOS>
# <SOS> business and <EOS>
# 10074 tensor([2, 2, 2, 4]) torch.Size([4, 4])
# <SOS> leaving off <EOS>
# <SOS> grand whimper <EOS>
# <SOS> piccoli 's <EOS>
# <SOS> is amazing <EOS>
# 10075 tensor([2, 1, 2, 2]) torch.Size([4, 4])
# <SOS> life-at-arm 's <EOS>
# <SOS> irritatingly transparent <EOS>
# <SOS> digits kidlets <EOS>
# <SOS> a no <EOS>
# 10076 tensor([3, 2, 4, 2]) torch.Size([4, 4])
# <SOS> the cleverness <EOS>
# <SOS> the weirdness <EOS>
# <SOS> pristine camerawork <EOS>
# <SOS> sobering meditation <EOS>
# 10077 tensor([2, 2, 2, 2]) torch.Size([4, 4])
# <SOS> take pictures <EOS>
# <SOS> it human <EOS>
# <SOS> no scenes <EOS>
# <SOS> upset or <EOS>
# 10078 tensor([2, 2, 2, 2]) torch.Size([4, 4])
# <SOS> young viewers <EOS>
# <SOS> 70-year-old godard <EOS>
# <SOS> become , <EOS>
# <SOS> to judge <EOS>
# 10079 tensor([2, 2, 1, 2]) torch.Size([4, 4])
# <SOS> old crank <EOS>
# <SOS> light meter <EOS>
# <SOS> supposed injustices <EOS>
# <SOS> artistic world-at-large <EOS>
# 10080 tensor([2, 1, 1, 3]) torch.Size([4, 4])
# <SOS> correct them <EOS>
# <SOS> guilt-suffused melodrama <EOS>
# <SOS> poor casting <EOS>
# <SOS> constantly touching <EOS>
# 10081 tensor([3, 2, 0, 2]) torch.Size([4, 4])
# <SOS> creative act <EOS>
# <SOS> than monty <EOS>
# <SOS> severe flaws <EOS>
# <SOS> director yu <EOS>
# 10082 tensor([2, 1, 4, 2]) torch.Size([4, 4])
# <SOS> more interested <EOS>
# <SOS> gross-out humor <EOS>
# <SOS> well-thought stunts <EOS>
# <SOS> 10,000 times <EOS>
# 10083 tensor([2, 3, 1, 2]) torch.Size([4, 4])
# <SOS> wants desperately <EOS>
# <SOS> fanciful film <EOS>
# <SOS> typical problems <EOS>
# <SOS> average people <EOS>
# 10084 tensor([1, 3, 2, 2]) torch.Size([4, 4])
# <SOS> dodgy mixture <EOS>
# <SOS> cutesy romance <EOS>
# <SOS> existing photos <EOS>
# <SOS> no movies <EOS>
# 10085 tensor([3, 1, 4, 2]) torch.Size([4, 4])
# <SOS> treats us <EOS>
# <SOS> aimless hodgepodge <EOS>
# <SOS> cinematic poetry <EOS>
# <SOS> city 's <EOS>
# 10086 tensor([3, 2, 2, 2]) torch.Size([4, 4])
# <SOS> old-world charm <EOS>
# <SOS> nearly everything <EOS>
# <SOS> as self-parody <EOS>
# <SOS> enormous amount <EOS>
# 10087 tensor([2, 2, 3, 3]) torch.Size([4, 4])
# <SOS> their lines <EOS>
# <SOS> ` uhhh <EOS>
# <SOS> fascinating profile <EOS>
# <SOS> deeply humanistic <EOS>
# 10088 tensor([2, 3, 3, 4]) torch.Size([4, 4])
# <SOS> 's witnessed <EOS>
# <SOS> surprisingly idealistic <EOS>
# <SOS> extraordinary faith <EOS>
# <SOS> deeply satisfying <EOS>
# 10089 tensor([3, 2, 1, 2]) torch.Size([4, 4])
# <SOS> yes . <EOS>
# <SOS> every note <EOS>
# <SOS> rings false <EOS>
# <SOS> extraordinarily silly <EOS>
# 10090 tensor([0, 2, 1, 2]) torch.Size([4, 4])
# <SOS> seriously bad <EOS>
# <SOS> with seriously <EOS>
# <SOS> warped logic <EOS>
# <SOS> kurt wimmer <EOS>
# 10091 tensor([2, 4, 2, 2]) torch.Size([4, 4])
# <SOS> screenplay level <EOS>
# <SOS> extraordinary journalism <EOS>
# <SOS> deft and <EOS>
# <SOS> thornberry stuff <EOS>
# 10092 tensor([2, 3, 2, 2]) torch.Size([4, 4])
# <SOS> wedgie heaven <EOS>
# <SOS> ingenious and <EOS>
# <SOS> despair or <EOS>
# <SOS> the whodunit <EOS>
# 10093 tensor([0, 3, 2, 3]) torch.Size([4, 4])
# <SOS> poo . <EOS>
# <SOS> count on <EOS>
# <SOS> a killer <EOS>
# <SOS> some success <EOS>
# 10094 tensor([2, 3, 2, 1]) torch.Size([4, 4])
# <SOS> with documentaries <EOS>
# <SOS> camera movements <EOS>
# <SOS> school undergrad <EOS>
# <SOS> maudlin ending <EOS>
# 10095 tensor([2, 2, 3, 1]) torch.Size([4, 4])
# <SOS> gotten him <EOS>
# <SOS> film school <EOS>
# <SOS> humorous observations <EOS>
# <SOS> general absurdity <EOS>
# 10096 tensor([1, 2, 2, 2]) torch.Size([4, 4])
# <SOS> condescending stereotypes <EOS>
# <SOS> mentally ill <EOS>
# <SOS> the match <EOS>
# <SOS> every print <EOS>
# 10097 tensor([2, 2, 3, 2]) torch.Size([4, 4])
# <SOS> fancy table <EOS>
# <SOS> macaroni and <EOS>
# <SOS> rocks . <EOS>
# <SOS> new angle <EOS>
# 10098 tensor([1, 2, 3, 2]) torch.Size([4, 4])
# <SOS> tireless story <EOS>
# <SOS> think twice <EOS>
# <SOS> booking passage <EOS>
# <SOS> screenwriting parlance <EOS>
# 10099 tensor([1, 2, 3, 1]) torch.Size([4, 4])
# <SOS> too difficult <EOS>
# <SOS> a text <EOS>
# <SOS> first-rate cast <EOS>
# <SOS> struggling nobody <EOS>

# %%
class Classifier(nn.Module):
    def __init__(self, vocab_size, nemb, nhid, nclass, nlayer=2):
        super(Classifier, self).__init__()
        self.emb = nn.Embedding(num_embeddings=vocab_size, embedding_dim=nemb)
        self.rnn = nn.GRU(input_size=nemb, hidden_size=nhid, num_layers=nlayer)
        self.fc = nn.Linear(nhid, nclass)
        
    def forward(self, x, hidden_state):
        emb = self.emb(x)
        rnn_output, hidden_state = self.rnn(emb, hidden_state)
        logits = self.fc(rnn_output)
        return logits

# %%
rnn = Classifier(len(vocab), 300, 512, 5)
